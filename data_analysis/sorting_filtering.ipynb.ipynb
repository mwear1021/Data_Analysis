# %% [markdown]
# Setup

# %%
# !pip install pandas
# Out:
# ...
#   Using cached numpy-2.3.2-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 11.0/11.0 MB 62.7 MB/s  0:00:00
# Using cached numpy-2.3.2-cp312-cp312-win_amd64.whl (12.8 MB)
# ...
#
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------- ----------------------------- 1/4 [tzdata]
#    ---------- ----------------------------- 1/4 [tzdata]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
# ...

# %%
import pandas as pd
vehicles = pd.read_csv('vehicles.csv')
vehicles.head()
# Out:
#       id                          model  year transmission   manufacturer  \
# 0  12988  amg e53 4matic+ (convertible)  2022         auto  mercedes-benz
# 1    689                  avalanche ffv  2007         auto      chevrolet
# 2    950                         impala  2010         auto      chevrolet
# 3    250                   yukon xl ffv  2004         auto            gmc
# 4  13089                    sf90 spyder  2022         auto        ferrari
#
#   vehicle_type                     fuel fuel_configuration  best_mpge
# 0  sedan/wagon          hybrid electric    hybrid electric       28.0
# 1       pickup            ethanol (e85)      flexible fuel       21.0
# 2  sedan/wagon            ethanol (e85)      flexible fuel       29.0
# 3          suv            ethanol (e85)      flexible fuel       18.0
# 4  sedan/wagon  plug-in hybrid electric    hybrid electric       19.0

# %% [markdown]
# 1. Sort `vehicles` by fuel from A to Z.

# %%
vehicles.sort_values(by='fuel')
# Out:
#          id                model  year transmission    manufacturer  \
# 604   12912         suburban 4wd  2022         auto       chevrolet
# 123   12038          terrain awd  2019         auto             gmc
# 564   12036      cruze hatchback  2019         auto       chevrolet
# 1223  11833          equinox fwd  2018         auto       chevrolet
# 1241  11836           canyon 4wd  2018         auto             gmc
# ...     ...                  ...   ...          ...             ...
# 925      21  econoline clubwagon  1998         auto            ford
# 451     220              express  2002         auto  quantum-procon
# 1128    221              express  2002         auto  quantum-procon
# 1486     15                f-150  1998      unknown            ford
# 89       42            econoline  1999         auto            ford
#
#      vehicle_type             fuel fuel_configuration  best_mpge
# 604           suv  biodiesel (b20)          dedicated       26.0
# ...

# %% [markdown]
# 2. Sort `vehicles` by `best_mpge` from highest to lowest. From the result, select the first 25 rows and the columns from `year` through `vehicle_type`.

# %%
best_mpg_vehicles = vehicles.sort_values(by = 'best_mpge')
best_mpg_vehicles.iloc[0:25,2:6]
# Out:
#       year transmission manufacturer vehicle_type
# 526   2005         auto          gmc       pickup
# 2054  2004         auto    chevrolet       pickup
# 1193  2004         auto          gmc       pickup
# 1189  2004         auto          gmc       pickup
# 268   1995      unknown        dodge  sedan/wagon
# 634   2005         auto          gmc       pickup
# 300   2006         auto          gmc       pickup
# 259   2006         auto    chevrolet       pickup
# 1140  2006         auto    chevrolet       pickup
# 193   2003         auto          gmc       pickup
# 189   2003         auto    chevrolet       pickup
# 2364  2006         auto          gmc       pickup
# 1111  2005         auto    chevrolet       pickup
# 859   2004         auto    chevrolet       pickup
# 2255  2005         auto    chevrolet       pickup
# 1596  2009         auto       hummer          suv
# 875   2001         auto         ford       pickup
# 923   2000         auto         ford          van
# ...

# %% [markdown]
# 3. Sort `vehicles` by fuel from A to Z, and then for each fuel by `best_mpge` from highest to lowest.

# %%
fuel_type = vehicles.sort_values(by='fuel')
fuel_type.sort_values(by='best_mpge', ascending=False)
# Out:
#          id                            model  year transmission manufacturer  \
# 1507  11640                            ioniq  2017         auto      hyundai
# 159   11844                   ioniq electric  2018         auto      hyundai
# 511   12752  model 3 standard range plus rwd  2021         auto        tesla
# 2142  12061                   ioniq electric  2019         auto      hyundai
# 647   12370      model 3 standard range plus  2020         auto        tesla
# ...     ...                              ...   ...          ...          ...
# 2255    398                        silverado  2005         auto    chevrolet
# 634     386                           sierra  2005         auto          gmc
# 526     383                           sierra  2005         auto          gmc
# 2054    251                        silverado  2004         auto    chevrolet
# 268     643                     intrepid ffv  1995      unknown        dodge
#
# ...

# %% [markdown]
# 4. Use Python code to check if `'auto'` is equal to `'manual'`.

# %%
'auto' == 'maunal'
# Out:
# False

# %% [markdown]
# 5. Create a Boolean mask that is `True` whenever `transmission` is `manual`.

# %%
is_manual = (vehicles['transmission'] == 'manual')
is_manual.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: transmission, dtype: bool

# %% [markdown]
# 6. Use the Boolean mask from 5 to filter `vehicles` down to only manual transmission vehicles. Assign the result to the variable `manual`.

# %%
manual = vehicles[is_manual]
manual.head(n=10)
# Out:
#          id                 model  year transmission   manufacturer  \
# 132     960               hhr 2wd  2010       manual      chevrolet
# 141   10144          regal manual  2011       manual          buick
# 273     215                savana  2002       manual            gmc
# 299   10093              civic gx  2011       manual          honda
# 325     668  c230 sport sedan ffv  2007       manual  mercedes-benz
# 370     193            gmc sierra  2002       manual            gmc
# 417   11647  a5 cabriolet quattro  2017       manual           audi
# 954     294          civic hybrid  2003       manual          honda
# 1093  11830                 cruze  2018       manual      chevrolet
# 1116  10149        hhr fwd manual  2011       manual      chevrolet
#
#      vehicle_type                          fuel fuel_configuration  best_mpge
# 132           suv                 ethanol (e85)      flexible fuel       32.0
# ...

# %% [markdown]
# 7. We've created a count of manual transmission vehicles by year. Add code to sort the result by year from earliest to latest. What do you notice?

# %%
manual.sort_values(by='year')
# Out:
#          id                 model  year transmission   manufacturer  \
# 1744    139               insight  2001       manual          honda
# 273     215                savana  2002       manual            gmc
# 1285    216               express  2002       manual      chevrolet
# 370     193            gmc sierra  2002       manual            gmc
# 2451    192             silverado  2002       manual      chevrolet
# 2405    211               insight  2002       manual          honda
# 2291    217             silverado  2002       manual      chevrolet
# 1907    218                sierra  2002       manual            gmc
# 2456    231                 civic  2002       manual          honda
# 954     294          civic hybrid  2003       manual          honda
# 1424    293               insight  2003       manual          honda
# 2466    323               insight  2004       manual          honda
# 1761    322          civic hybrid  2004       manual          honda
# ...

# %% [markdown]
# 8. Create a Boolean mask that is `True` when `vehicle_type` is `suv` or `pickup`. Filter `vehicles` down to only the `True` rows.

# %%
is_suv_or_pickup = vehicles[(vehicles['vehicle_type'] == 'suv') | (vehicles['vehicle_type'] == 'pickup')]
is_suv_or_pickup
# Out:
#          id                           model  year transmission   manufacturer  \
# 1       689                   avalanche ffv  2007         auto      chevrolet
# 3       250                    yukon xl ffv  2004         auto            gmc
# 5     12302                   silverado 4wd  2020         auto      chevrolet
# 6     12989      amg gle 53 4matic+ (coupe)  2022         auto  mercedes-benz
# 8     10584               sierra c / k 1500  2013         auto            gmc
# ...     ...                             ...   ...          ...            ...
# 2510  11664                         journey  2017         auto          dodge
# 2512  12998  sierra 4wd - mud terrain tires  2022         auto            gmc
# 2513    885               tahoe 1500 hybrid  2009         auto      chevrolet
# 2514  12823               defender 110 mhev  2022         auto     land rover
# 2515  11559                  gla 250 4matic  2016         auto  mercedes-benz
#
# ...

# %% [markdown]
# 9. Create a Boolean mask that is `True` when `vehicle_type` is neither `suv` nor `pickup`. Filter `vehicles` down to only the `True` rows.

# %%
is_suv = vehicles['vehicle_type'] == 'suv'
is_pickup = vehicles['vehicle_type'] == 'pickup'

is_either = is_suv | is_pickup
is_neither = ~is_either
vehicles[is_neither]
# Out:
#          id                          model  year transmission   manufacturer  \
# 0     12988  amg e53 4matic+ (convertible)  2022         auto  mercedes-benz
# 2       950                         impala  2010         auto      chevrolet
# 4     13089                    sf90 spyder  2022         auto        ferrari
# 7     12875                 avalon hybrid   2022         auto         toyota
# 10    10539                         fortwo  2013      unknown          smart
# ...     ...                            ...   ...          ...            ...
# 2511  11138              express 3500, 2wd  2014         auto      chevrolet
# 2516  12941                     sienna awd  2022         auto         toyota
# 2517    457              grand caravan ffv  2006         auto          dodge
# 2518  12706                santa fe hybrid  2021         auto        hyundai
# 2519  12390                          ioniq  2020         auto        hyundai
#
# ...

# %% [markdown]
# 10. Create a Boolean mask that is `True` whenever `fuel` is `hybrid electric` and `best_mpge` is below average (less than 40). Filter `vehicles` down to only the rows that are `True`.

# %%
is_hybrid = vehicles['fuel'] == 'hybrid electric'
lt40_mpg = vehicles['best_mpge'] < 40
combined = is_hybrid & lt40_mpg

vehicles[combined]
# Out:
#          id                          model  year transmission   manufacturer  \
# 0     12988  amg e53 4matic+ (convertible)  2022         auto  mercedes-benz
# 6     12989     amg gle 53 4matic+ (coupe)  2022         auto  mercedes-benz
# 9     12864                   x6 xdrive40i  2022         auto            bmw
# 14    12599                     a5 quattro  2021         auto           audi
# 18      695                         sierra  2007         auto            gmc
# ...     ...                            ...   ...          ...            ...
# 2508  12128                     nsx hybrid  2019         auto          acura
# 2513    885              tahoe 1500 hybrid  2009         auto      chevrolet
# 2514  12823              defender 110 mhev  2022         auto     land rover
# 2516  12941                     sienna awd  2022         auto         toyota
# 2518  12706                santa fe hybrid  2021         auto        hyundai
#
# ...
